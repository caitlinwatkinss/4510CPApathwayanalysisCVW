# %% [markdown]
# # Research Questions Analysis

# %%
from analysis.analysis_pipeline import main

main()

# %%
import pandas as pd

pd.read_csv('../outputs/tables/rq1_awareness_by_intent.csv').head()
