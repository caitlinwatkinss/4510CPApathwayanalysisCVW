# %% [markdown]
# # Survey Data Quick Audit

# %%
import pandas as pd
from analysis import utils

data_path = '../Alternative CPA Pathways Survey_December 31, 2025_09.45.csv'
df = pd.read_csv(data_path)
df = utils.trim_and_normalize_missing(df)
df.shape

# %%
missing = df.isna().mean().sort_values(ascending=False)
missing.head(20)

# %%
df.head()
